# %%
# %run device_query.py
# Out:
# CUDA device query (PyCUDA version)
#
# Detected 1 CUDA Capable device(s)
#
# Device 0: NVIDIA GeForce GTX 1050 Ti
# 	 Compute Capability: 6.1
# 	 Total Memory: 4095 megabytes
# 	 (6) Multiprocessors, (128) CUDA Cores / Multiprocessor: 768 CUDA Cores
# 	 ASYNC_ENGINE_COUNT: 1
# 	 CAN_MAP_HOST_MEMORY: 1
# 	 CAN_USE_HOST_POINTER_FOR_REGISTERED_MEM: 0
# 	 CLOCK_RATE: 1417500
# 	 COMPUTE_CAPABILITY_MAJOR: 6
# 	 COMPUTE_CAPABILITY_MINOR: 1
# 	 COMPUTE_MODE: DEFAULT
# 	 COMPUTE_PREEMPTION_SUPPORTED: 1
# 	 CONCURRENT_KERNELS: 1
# 	 CONCURRENT_MANAGED_ACCESS: 0
# 	 DIRECT_MANAGED_MEM_ACCESS_FROM_HOST: 0
# 	 ECC_ENABLED: 0
# 	 GENERIC_COMPRESSION_SUPPORTED: 0
# 	 GLOBAL_L1_CACHE_SUPPORTED: 1
# 	 GLOBAL_MEMORY_BUS_WIDTH: 128
# 	 GPU_OVERLAP: 1
# 	 HANDLE_TYPE_POSIX_FILE_DESCRIPTOR_SUPPORTED: 0
# 	 HANDLE_TYPE_WIN32_HANDLE_SUPPORTED: 1
# 	 HANDLE_TYPE_WIN32_KMT_HANDLE_SUPPORTED: 1
# 	 HOST_NATIVE_ATOMIC_SUPPORTED: 0
# 	 INTEGRATED: 0
# 	 KERNEL_EXEC_TIMEOUT: 1
# 	 L2_CACHE_SIZE: 1048576
# ...

# %%
# %run device_query.py
# Out:
# CUDA device query (PyCUDA version)
#
# Detected 1 CUDA Capable device(s)
#
# Device 0: NVIDIA GeForce RTX 4070 SUPER
# 	 Compute Capability: 8.9
# 	 Total Memory: 12281 megabytes
# 	 (56) Multiprocessors, (128) CUDA Cores / Multiprocessor: 7168 CUDA Cores
# 	 ASYNC_ENGINE_COUNT: 1
# 	 CAN_MAP_HOST_MEMORY: 1
# 	 CAN_USE_HOST_POINTER_FOR_REGISTERED_MEM: 0
# 	 CLOCK_RATE: 2475000
# 	 COMPUTE_CAPABILITY_MAJOR: 8
# 	 COMPUTE_CAPABILITY_MINOR: 9
# 	 COMPUTE_MODE: DEFAULT
# 	 COMPUTE_PREEMPTION_SUPPORTED: 1
# 	 CONCURRENT_KERNELS: 1
# 	 CONCURRENT_MANAGED_ACCESS: 0
# 	 DIRECT_MANAGED_MEM_ACCESS_FROM_HOST: 0
# 	 ECC_ENABLED: 0
# 	 GENERIC_COMPRESSION_SUPPORTED: 1
# 	 GLOBAL_L1_CACHE_SUPPORTED: 1
# 	 GLOBAL_MEMORY_BUS_WIDTH: 192
# 	 GPU_OVERLAP: 1
# 	 HANDLE_TYPE_POSIX_FILE_DESCRIPTOR_SUPPORTED: 0
# 	 HANDLE_TYPE_WIN32_HANDLE_SUPPORTED: 1
# 	 HANDLE_TYPE_WIN32_KMT_HANDLE_SUPPORTED: 1
# 	 HOST_NATIVE_ATOMIC_SUPPORTED: 0
# 	 INTEGRATED: 0
# 	 KERNEL_EXEC_TIMEOUT: 1
# 	 L2_CACHE_SIZE: 50331648
# ...
