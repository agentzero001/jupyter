# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.facecolor'] = '.0'
plt.rcParams['axes.facecolor'] = '.1'
plt.rcParams['axes.labelcolor'] = 'white'
plt.rcParams['text.color'] = 'white'
plt.rcParams['xtick.color'] = 'green'
plt.rcParams['ytick.color'] = 'green'
plt.rcParams['axes.edgecolor'] = 'purple'

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 100)
y = np.linspace(0, 5, 100)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.contour(X, Y, Z, colors='grey')

plt.subplot(1,2,2)
plt.contour(X, Y, Z, 20, cmap='inferno', alpha=.7);

# %%
#plt.colormaps()

# %%
plt.figure(figsize=(12,5))

plt.subplot(121)
plt.contourf(X, Y, Z, 20, cmap='inferno' ,alpha=.4)
plt.colorbar();

plt.subplot(122)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar();

# %% [markdown]
# -------------------------

# %% [markdown]
# --------------------

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure(figsize=(8,8))
fig.patch.set_facecolor('.2')
# ax1 = fig.add_subplot(221, projection='3d')
# ax2 = fig.add_subplot(222, projection='3d')
# ax3 = fig.add_subplot(223, projection='3d')
# ax4 = fig.add_subplot(224, projection='3d')

ax1, ax2, ax3, ax4 = [fig.add_subplot(2,2,i, projection='3d') for i in range(1,5)]
titles = ['contour3D', 'countour3D', 'wireframe', 'surface']

for ax, title in zip((ax1,ax2,ax3,ax4),titles):
    ax.set_facecolor('.2')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    ax.set_title(title)

ax1.contour3D(X, Y, Z, 50, cmap='binary')

ax2.contour3D(X, Y, Z, 50, cmap='binary')
ax2.view_init(60, 35)

ax3.plot_wireframe(X, Y, Z, color='black')

ax4.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none');

# %%
fig.patch.set_facecolor('.2')
ax = fig.add_subplot(111, projection='3d')
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('wireframe');

# %%
subplot1 = fig.add_subplot(2, 2, 1, projection='3d')
subplot2 = fig.add_subplot(2, 2, 2, projection='3d')
# subplot3 = fig.add_subplot(2, 2, 3, projection='3d')
# subplot4 = fig.add_subplot(2, 2, 4, projection='3d')

# %%
subplot1.contour3D(X, Y, Z, 50, cmap='binary')
subplot2.plot_wireframe(X, Y, Z, color='black')
plt.show()

# %%
plt.show()
