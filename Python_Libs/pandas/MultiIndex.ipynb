# %%
import pandas as pd
import numpy as np

# %%
f = lambda s: np.random.randint(low=10**7, high=10**8, size=s)

# %%
f(5), f((2,5))
# Out:
# (array([71123587, 95390370, 17561708, 49657497, 16450720]),
#  array([[81632863, 33284553, 60728370, 26269188, 59985216],
#         [56675905, 22140176, 26701085, 38527067, 45229605]]))

# %%
pd.MultiIndex(levels=[['a','b'],[0,1,2]], codes=[[0,1,0,1],[2,1,0,2]])
# Out:
# MultiIndex([('a', 2),
#             ('b', 1),
#             ('a', 0),
#             ('b', 2)],
#            )

# %%
pd.MultiIndex.from_tuples([('a', 5),('b',3),('c', 4)])
# Out:
# MultiIndex([('a', 5),
#             ('b', 3),
#             ('c', 4)],
#            )

# %%
pd.MultiIndex.from_tuples([('a', 5),('b',3),('c', 4)]).__dict__
# Out:
# {'_cache': {},
#  '_levels': FrozenList([['a', 'b', 'c'], [3, 4, 5]]),
#  '_codes': FrozenList([[0, 1, 2], [2, 0, 1]]),
#  '_names': [None, None],
#  'sortorder': None,
#  '_id': <object at 0x21be8edcb90>,
#  '_references': None}

# %%
index = pd.MultiIndex.from_product([{'A','B','C','D'},{1,2,3}], names=['first','second'])
index
# Out:
# MultiIndex([('D', 1),
#             ('D', 2),
#             ('D', 3),
#             ('B', 1),
#             ('B', 2),
#             ('B', 3),
#             ('C', 1),
#             ('C', 2),
#             ('C', 3),
#             ('A', 1),
#             ('A', 2),
#             ('A', 3)],
#            names=['first', 'second'])

# %%
index2 = pd.MultiIndex.from_product([{'A','B','C','D'}, {1,2,3}, {'first','second'}])
index2
# Out:
# MultiIndex([('D', 1, 'second'),
#             ('D', 1,  'first'),
#             ('D', 2, 'second'),
#             ('D', 2,  'first'),
#             ('D', 3, 'second'),
#             ('D', 3,  'first'),
#             ('B', 1, 'second'),
#             ('B', 1,  'first'),
#             ('B', 2, 'second'),
#             ('B', 2,  'first'),
#             ('B', 3, 'second'),
#             ('B', 3,  'first'),
#             ('C', 1, 'second'),
#             ('C', 1,  'first'),
#             ('C', 2, 'second'),
#             ('C', 2,  'first'),
#             ('C', 3, 'second'),
#             ('C', 3,  'first'),
#             ('A', 1, 'second'),
#             ('A', 1,  'first'),
#             ('A', 2, 'second'),
#             ('A', 2,  'first'),
#             ('A', 3, 'second'),
#             ('A', 3,  'first')],
#            )

# %%
S  = pd.Series(f(12), index=index)
#S2 = pd.Series(f(12), index=index)
 
S  = S.sort_index()

# %%
#S.index.names = [None, None]
S
# Out:
# first  second
# A      1         37273763
#        2         56275807
#        3         70302784
# B      1         29320437
#        2         34855029
#        3         18417103
# C      1         43441774
#        2         81471455
#        3         25212573
# D      1         75699933
#        2         97142981
#        3         52833877
# dtype: int32

# %%
df = S.unstack(level=-1)
df
# Out:
# second         1         2         3
# first
# A       37273763  56275807  70302784
# B       29320437  34855029  18417103
# C       43441774  81471455  25212573
# D       75699933  97142981  52833877

# %%
S = df.stack()

# %%
df = pd.DataFrame(S,columns=['population'])
df
# Out:
#               population
# first second
# A     1         37273763
#       2         56275807
#       3         70302784
# B     1         29320437
#       2         34855029
#       3         18417103
# C     1         43441774
#       2         81471455
#       3         25212573
# D     1         75699933
#       2         97142981
#       3         52833877

# %%
df['population2'] = f(12)
df.index
# Out:
# MultiIndex([('A', 1),
#             ('A', 2),
#             ('A', 3),
#             ('B', 1),
#             ('B', 2),
#             ('B', 3),
#             ('C', 1),
#             ('C', 2),
#             ('C', 3),
#             ('D', 1),
#             ('D', 2),
#             ('D', 3)],
#            names=['first', 'second'])

# %%
df
# Out:
#               population  population2
# first second
# A     1         37273763     35206490
#       2         56275807     76620300
#       3         70302784     98419381
# B     1         29320437     90446228
#       2         34855029     84768964
#       3         18417103     84802168
# C     1         43441774     69714199
#       2         81471455     59259539
#       3         25212573     43234746
# D     1         75699933     31881514
#       2         97142981     26907583
#       3         52833877     16578185

# %%
df.loc['D', 2]
# Out:
# population     97142981
# population2    26907583
# Name: (D, 2), dtype: int32

# %%
ex_ind = pd.MultiIndex.from_product([{'A','B','C','D'},{1,2,3},{0,1}], names=['first','second','third'])
ex_ind2 = pd.MultiIndex.from_product([{'A','B','C','D'},{1,2,3},{2,3}], names=['first','second','third'])
ex_ind.shape
# Out:
# (24,)

# %%
S1 = pd.Series(f(24), index = ex_ind)
S2 = pd.Series(f(24), index = ex_ind2)  
my_series = pd.concat((S1,S2)).sort_index()
my_series
# Out:
# first  second  third
# A      1       0        80112871
#                1        17174993
#                2        58259788
#                3        72286989
#        2       0        49157003
#                1        39400292
#                2        53321310
#                3        37282934
#        3       0        59435912
#                1        88181516
#                2        45669347
#                3        26359551
# B      1       0        10837620
#                1        33900585
#                2        25326826
#                3        81689202
#        2       0        29209576
#                1        33986727
#                2        98063736
#                3        87207489
#        3       0        19043891
#                1        54160895
#                2        75158591
#                3        17110303
# C      1       0        60328676
#                1        44914738
#                2        67299662
#                3        75945724
#        2       0        91885228
#                1        39427162
#                2        79475117
#                3        12487579
#        3       0        32618235
#                1        66907579
#                2        91403596
#                3        99497627
# D      1       0        16983104
#                1        80692189
#                2        85576939
#                3        16696628
#        2       0        22517688
#                1        86992287
#                2        46499414
#                3        26684255
#        3       0        26810685
#                1        90235565
#                2        37238341
#                3        58352782
# dtype: int32

# %%
data_frame = my_series.unstack().unstack().unstack().unstack().unstack().stack().unstack()
data_frame #i guess there is some symmetry
# Out:
# first          A                             B                             C  \
# second         1         2         3         1         2         3         1
# third
# 0       80112871  49157003  59435912  10837620  29209576  19043891  60328676
# 1       17174993  39400292  88181516  33900585  33986727  54160895  44914738
# 2       58259788  53321310  45669347  25326826  98063736  75158591  67299662
# 3       72286989  37282934  26359551  81689202  87207489  17110303  75945724
#
# first                              D
# second         2         3         1         2         3
# third
# 0       91885228  32618235  16983104  22517688  26810685
# 1       39427162  66907579  80692189  86992287  90235565
# 2       79475117  91403596  85576939  46499414  37238341
# 3       12487579  99497627  16696628  26684255  58352782

# %%
data_frame['A',3][2]
# Out:
# 45669347

# %%
data_frame.reset_index()
# Out:
# first  third         A                             B                      \
# second               1         2         3         1         2         3
# 0          0  80112871  49157003  59435912  10837620  29209576  19043891
# 1          1  17174993  39400292  88181516  33900585  33986727  54160895
# 2          2  58259788  53321310  45669347  25326826  98063736  75158591
# 3          3  72286989  37282934  26359551  81689202  87207489  17110303
#
# first          C                             D
# second         1         2         3         1         2         3
# 0       60328676  91885228  32618235  16983104  22517688  26810685
# 1       44914738  39427162  66907579  80692189  86992287  90235565
# 2       67299662  79475117  91403596  85576939  46499414  37238341
# 3       75945724  12487579  99497627  16696628  26684255  58352782

# %%
df2 = pd.DataFrame({'c1': f(24), 'c2': f(24)}, index = ex_ind).stack().reset_index()
df2 = df2.set_index(df2.columns[0])
df2[:5]
# Out:
#        second  third level_3         0
# first
# D           1      0      c1  61312698
# D           1      0      c2  92148513
# D           1      1      c1  19559684
# D           1      1      c2  90014386
# D           2      0      c1  79779036

# %%
df2.loc['A'].T
# Out:
# first           A         A         A         A         A         A         A  \
# second          1         1         1         1         2         2         2
# third           0         0         1         1         0         0         1
# level_3        c1        c2        c1        c2        c1        c2        c1
# 0        25528221  36068223  68568942  10284524  69779812  77444808  98990446
#
# first           A         A         A         A         A
# second          2         3         3         3         3
# third           1         0         0         1         1
# level_3        c2        c1        c2        c1        c2
# 0        24350382  70142487  65821819  34108212  66564651

# %%
pd.DataFrame([f(24),f(24)], columns=ex_ind).T
# Out:
#                            0         1
# first second third
# D     1      0      37846169  81592923
#              1      68681745  76144953
#       2      0      82874629  19068802
#              1      11457641  33079753
#       3      0      28927113  61845136
#              1      69618712  76829649
# B     1      0      56371241  57376217
#              1      64220406  77462989
#       2      0      49449410  86284785
#              1      30875888  35913970
#       3      0      70580523  57342145
#              1      33700108  73725410
# C     1      0      52815079  19541896
#              1      95494729  52151762
#       2      0      23819536  78985820
#              1      98588947  18318774
#       3      0      29304997  81795097
#              1      36771744  39121604
# A     1      0      49411161  43218014
#              1      84965502  38439556
#       2      0      78358009  62453813
#              1      20062903  60540274
#       3      0      77654288  21930110
#              1      45281283  50125745

# %%
index = pd.MultiIndex.from_product([[2013, 2014], [1, 2]], names=['year', 'visit'])
columns = pd.MultiIndex.from_product([['Bob', 'Guido', 'Sue'], ['HR', 'Temp']], names=['subject', 'type'])

data = np.round(np.random.randn(4, 6), 1)
data[:, ::2] *= 10
data += 37

health_data = pd.DataFrame(data, index=index, columns=columns)
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      50.0  36.5  30.0  36.3  46.0  36.8
#      2      44.0  35.5  32.0  36.4  30.0  37.3
# 2014 1      52.0  36.8  57.0  38.0  39.0  37.0
#      2      34.0  37.7  25.0  37.1  40.0  36.1

# %%
#one way, but very weird imo
health_data.loc[(slice(None), 1), :]
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      50.0  36.5  30.0  36.3  46.0  36.8
# 2014 1      52.0  36.8  57.0  38.0  39.0  37.0

# %%
#access like this is much easier
health_data.xs(1, level='visit')
# Out:
# subject   Bob       Guido         Sue
# type       HR  Temp    HR  Temp    HR  Temp
# year
# 2013     50.0  36.5  30.0  36.3  46.0  36.8
# 2014     52.0  36.8  57.0  38.0  39.0  37.0

# %%
health_data.xs(2013, level='year')
# Out:
# subject   Bob       Guido         Sue
# type       HR  Temp    HR  Temp    HR  Temp
# visit
# 1        50.0  36.5  30.0  36.3  46.0  36.8
# 2        44.0  35.5  32.0  36.4  30.0  37.3

# %%
#access multiIndexed columns
health_data.loc[:, ('Guido', 'HR')]
# Out:
# year  visit
# 2013  1        30.0
#       2        32.0
# 2014  1        57.0
#       2        25.0
# Name: (Guido, HR), dtype: float64

# %%
#access a particular value in a df where both rows and columns have multiIndex
health_data.loc[(2013,1), ('Guido', 'HR')]
# Out:
# 30.0

# %%
health_data.loc[(2013,1)]
# Out:
# subject  type
# Bob      HR      50.0
#          Temp    36.5
# Guido    HR      30.0
#          Temp    36.3
# Sue      HR      46.0
#          Temp    36.8
# Name: (2013, 1), dtype: float64

# %%
health_data.loc[:, 'Bob']
# Out:
# type          HR  Temp
# year visit
# 2013 1      50.0  36.5
#      2      44.0  35.5
# 2014 1      52.0  36.8
#      2      34.0  37.7

# %%
#some other type of combination
health_data.loc[2013].loc[1]
# Out:
# subject  type
# Bob      HR      50.0
#          Temp    36.5
# Guido    HR      30.0
#          Temp    36.3
# Sue      HR      46.0
#          Temp    36.8
# Name: 1, dtype: float64

# %%
health_data.iloc[0, 1]
# Out:
# 36.5

# %%
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      50.0  36.5  30.0  36.3  46.0  36.8
#      2      44.0  35.5  32.0  36.4  30.0  37.3
# 2014 1      52.0  36.8  57.0  38.0  39.0  37.0
#      2      34.0  37.7  25.0  37.1  40.0  36.1

# %%
data_mean = health_data.groupby(level='year').mean()
data_mean
# Out:
# subject   Bob        Guido          Sue
# type       HR   Temp    HR   Temp    HR   Temp
# year
# 2013     47.0  36.00  31.0  36.35  38.0  37.05
# 2014     43.0  37.25  41.0  37.55  39.5  36.55

# %%
data_mean.mean(axis=1)
# Out:
# year
# 2013    37.566667
# 2014    39.141667
# dtype: float64

# %%
data_mean.T.groupby('type').mean()
# Out:
# year       2013       2014
# type
# HR    38.666667  41.166667
# Temp  36.466667  37.116667

# %%
health_data.stack(level=0)
# Out:
# type                  HR  Temp
# year visit subject
# 2013 1     Bob      50.0  36.5
#            Guido    30.0  36.3
#            Sue      46.0  36.8
#      2     Bob      44.0  35.5
#            Guido    32.0  36.4
#            Sue      30.0  37.3
# 2014 1     Bob      52.0  36.8
#            Guido    57.0  38.0
#            Sue      39.0  37.0
#      2     Bob      34.0  37.7
#            Guido    25.0  37.1
#            Sue      40.0  36.1

# %%
health_data_stacked = health_data.stack(level=-1)
health_data_stacked
# Out:
# subject           Bob  Guido   Sue
# year visit type
# 2013 1     HR    50.0   30.0  46.0
#            Temp  36.5   36.3  36.8
#      2     HR    44.0   32.0  30.0
#            Temp  35.5   36.4  37.3
# 2014 1     HR    52.0   57.0  39.0
#            Temp  36.8   38.0  37.0
#      2     HR    34.0   25.0  40.0
#            Temp  37.7   37.1  36.1

# %%
one_more_time = health_data_stacked.stack()
one_more_time
# Out:
# year  visit  type  subject
# 2013  1      HR    Bob        50.0
#                    Guido      30.0
#                    Sue        46.0
#              Temp  Bob        36.5
#                    Guido      36.3
#                    Sue        36.8
#       2      HR    Bob        44.0
#                    Guido      32.0
#                    Sue        30.0
#              Temp  Bob        35.5
#                    Guido      36.4
#                    Sue        37.3
# 2014  1      HR    Bob        52.0
#                    Guido      57.0
#                    Sue        39.0
#              Temp  Bob        36.8
#                    Guido      38.0
#                    Sue        37.0
#       2      HR    Bob        34.0
#                    Guido      25.0
#                    Sue        40.0
#              Temp  Bob        37.7
#                    Guido      37.1
#                    Sue        36.1
# dtype: float64

# %%
one_more_time.info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 24 entries, (2013, 1, 'HR', 'Bob') to (2014, 2, 'Temp', 'Sue')
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 24 non-null     float64
# dtypes: float64(1)
# memory usage: 1008.0+ bytes

# %%
one_more_time.describe()
# Out:
# count    24.000000
# mean     38.354167
# std       7.146965
# min      25.000000
# 25%      35.950000
# 50%      36.900000
# 75%      39.250000
# max      57.000000
# dtype: float64

# %%
health_data.loc[:,('Guido','HR')]
# Out:
# year  visit
# 2013  1        30.0
#       2        32.0
# 2014  1        57.0
#       2        25.0
# Name: (Guido, HR), dtype: float64
