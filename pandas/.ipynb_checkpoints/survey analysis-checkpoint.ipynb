# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/survey_results_public.csv', index_col= 'Respondent')

# %%
df.shape
# Out:
# (64461, 60)

# %%
#df.columns

# %%
#df.info()

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df.loc[1,'DevType']
# Out:
# 'Developer, desktop or enterprise applications;Developer, full-stack'

# %%
df['Country'].value_counts()[:6]
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
# France             1898
# Name: Country, dtype: int64

# %%
plt.figure(facecolor = '0.3')
plt.axes().set_facecolor('grey')

top_country = df['Country'].value_counts()[:5]

plt.bar(top_country.index,top_country, color = 'black')
plt.show()

# %%
filt = (df['Country'] == 'Germany')

filt2 = (df['Country'] == 'United States') & (df['Hobbyist'] == 'Yes')

len(df.loc[filt]) 

b = len(df.loc[filt2]) 

filt3 = df['ConvertedComp'] > 70000

# %%
df.loc[filt3]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# ...                                                       ...      ...   ...
# 65586                          I am a developer by profession      Yes   NaN
# 65589                          I am a developer by profession      Yes   NaN
# 65602       I am not primarily a developer, but I write co...      Yes   NaN
# 65604                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
#
# ...

# %%
contries = ['United States', 'Germany', 'India', 'United Kingdom', 'Canada']
filter3 = df['Country'].isin(contries)

# %%
df.loc[-filter3, 'Country']
# Out:
# Respondent
# 3        Russian Federation
# 4                   Albania
# 9                   Tunisia
# 12                    Spain
# 13              Netherlands
#                 ...
# 64567           Netherlands
# 64867               Morocco
# 64898              Viet Nam
# 64925                Poland
# 65112                 Spain
# Name: Country, Length: 33612, dtype: object

# %%
filter4 = df['LanguageWorkedWith'].str.contains('Python', na = False)

# %%
df.loc[filter4, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
#df.columns = range(1,61,1)

# %%
filter5 = df['Country'].isin(['United States', 'Germany', 'India', 'United Kingdom', 'Canada'])

# %%
df.loc[-filter5, 'Country']
# Out:
# Respondent
# 3        Russian Federation
# 4                   Albania
# 9                   Tunisia
# 12                    Spain
# 13              Netherlands
#                 ...
# 64567           Netherlands
# 64867               Morocco
# 64898              Viet Nam
# 64925                Poland
# 65112                 Spain
# Name: Country, Length: 33612, dtype: object

# %%
filter6 = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filter6,'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object
