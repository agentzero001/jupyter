# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
plt.rcParams['figure.facecolor'] = '.0'
plt.rcParams['axes.facecolor'] = '.1'
plt.rcParams['axes.labelcolor'] = 'white'
plt.rcParams['text.color'] = 'white'
plt.rcParams['xtick.color'] = 'green'
plt.rcParams['ytick.color'] = 'green'
plt.rcParams['axes.edgecolor'] = 'purple'
plt.rcParams['text.usetex'] = False

# %%
func = lambda x: 1/x
positive_values = np.linspace(.01,15,1000)
negative_values = np.linspace(-15,-.01,1000)

graph_pos = np.array(list(map(func, positive_values)))
graph_neg = np.array(list(map(func, negative_values)))
plt.axes().set_facecolor('black')
plt.axhline(y=0,color='grey', zorder=0,alpha=.5)
plt.axvline(x=0, color='grey', zorder=0,alpha=.5)
plt.plot(negative_values, graph_neg, color='orange')
plt.plot(positive_values, graph_pos, color='orange')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.title(r'f(x) = $\frac{1}{x}$')
plt.axis([-6,6,-6,6]);
plt.show()

# %%
func = lambda x: (x**2 - 4) / (x**2 - 4*x)

positive_values2 = np.linspace(4.001, 10, 1000) 
positive_values = np.linspace(.01, 3.99, 1000)
negative_values = np.linspace(-15, -.01, 1000)

graph_pos = np.array(list(map(func, positive_values)))
graph_pos2 = np.array(list(map(func, positive_values2)))
graph_neg = np.array(list(map(func, negative_values)))
plt.axes().set_facecolor('black')
plt.axhline(y=0,color='grey', zorder=0,alpha=.5)
plt.axvline(x=0, color='grey', zorder=0,alpha=.5)
plt.plot(negative_values, graph_neg, color='orange')
plt.plot(positive_values, graph_pos, color='orange')
plt.plot(positive_values2, graph_pos2, color='orange')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.title(r'f(x) = $\frac{x^2 - 4}{x^2 - 4x}$',fontsize='16')
plt.axis([-6,6,-6,6]);
plt.show()

# %%
func = lambda x: (9) / (x**2 - 9)

positive_values2 = np.linspace(3.001, 10, 1000) 
positive_values = np.linspace(-2.999, 2.999, 1000)
negative_values = np.linspace(-10, -3.001, 1000)

graph_pos = np.array(list(map(func, positive_values)))
graph_pos2 = np.array(list(map(func, positive_values2)))
graph_neg = np.array(list(map(func, negative_values)))
plt.axes().set_facecolor('black')
plt.axhline(y=0,color='grey', zorder=0,alpha=.5)
plt.axvline(x=0, color='grey', zorder=0,alpha=.5)
plt.plot(negative_values, graph_neg, color='orange')
plt.plot(positive_values, graph_pos, color='orange')
plt.plot(positive_values2, graph_pos2, color='orange')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.title(r'f(x) = $\frac{9}{x^2-9}$',fontsize='16')
plt.axis([-6,6,-6,6]);
plt.show()

# %%
block1 = np.array([(0, 0), (-1, 0), (1, 0), (0, -1)])
block1_T = block1.T
block1.shape, block1_T.shape
# Out:
# ((4, 2), (2, 4))

# %%
c1 = lambda t: (2*np.sin(t), .5 *np.cos(t) + 2)
L  = np.linspace(0,np.pi*2,100)

circle = list(map(c1, L))
np_circle = np.array(circle)
plt.axes().set_facecolor('black')
plt.plot(np_circle[:,0], np_circle[:,1], color='orange', linestyle='dotted')
plt.scatter(block1.T[0], block1.T[1])
plt.axis('equal')

plt.show()

# %%
block1
# Out:
# array([[ 0,  0],
#        [-1,  0],
#        [ 1,  0],
#        [ 0, -1]])

# %%
rotation_matrix = np.array([[0, -1], [1, 0]])
block1_flipped = block1 @ rotation_matrix
block1_flipped
# Out:
# array([[ 0,  0],
#        [ 0,  1],
#        [ 0, -1],
#        [-1,  0]])

# %%
plt.axes().set_facecolor('black')
plt.scatter(block1_flipped.T[0], block1_flipped.T[1], c='grey', s=300,marker='s')
plt.scatter(block1.T[0], block1.T[1], c='orange')
plt.axis('equal')
plt.show()

# %%
rotation_matrix = np.array([[0, -1], [1, 0]])

vector1 = np.array((0,1))
pivot_point = np.array((2,1))
translated_vector1 = vector1 - pivot_point
rotated_translated_vector1 = translated_vector1 @ rotation_matrix
rotated_vector1 = rotated_translated_vector1 + pivot_point

# %%
def label_vector(vector, color):
    plt.text(*(vector + .2), '({},{})'.format(vector[0],vector[1]), c=color)

# %%
plt.axes().set_facecolor('black')
plt.scatter(*vector1, c='orange')
plt.scatter(*pivot_point, c='purple')
plt.scatter(*rotated_vector1, c='green')
plt.axhline(y=0,color='grey', zorder=0,alpha=.5)
plt.axvline(x=0, color='grey', zorder=0,alpha=.5)
label_vector(vector1, 'orange')
label_vector(pivot_point, 'purple')
label_vector(rotated_vector1, 'green')
plt.axis('equal')
plt.axis([-6,6,-6,6]);

# %%
t = np.linspace(0, 10*np.pi, 1000)  
r = np.random.randint(0,100, 1000)

x = r * np.cos(t)
y = r * np.sin(t)

plt.axes().set_facecolor('black')
plt.scatter(x, y, color='grey', linewidth=.4, s=10)
plt.axis('equal')

plt.show()

# %%
f_xy = lambda x, y: np.sin(x) ** 20 + np.cos(y * x) * np.cos(x)
f_x2 = lambda x: np.sin(x) ** 20 + np.cos(2 * x) * np.cos(x)


x = np.linspace(0, 5, 100)
y = np.linspace(0, 5, 100)


X, Y = np.meshgrid(x, y)
Z = f_xy(X, Y)

# %%
xs = np.linspace(0,10,1000)
ys = f_x2(xs)

# %%
plt.axes().set_facecolor('black')
plt.axhline(y=0,color='grey', zorder=0,alpha=.5)
plt.axvline(x=0, color='grey', zorder=0,alpha=.5)
plt.plot(xs,ys, color='grey')
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.1012451400962953, 1.1262801627870211)

# %%
# %matplotlib inline

# %%
-np.sin(np.pi), np.cos(np.pi+np.pi/2)
# Out:
# (-1.2246467991473532e-16, -1.8369701987210297e-16)

# %%
np.sin(.5+np.pi/2), np.cos(.5)
# Out:
# (0.8775825618903728, 0.8775825618903728)

# %%
from math import log

# %%
log(32)
# Out:
# 3.4657359027997265

# %%
log(16, 2)
# Out:
# 4.0

# %%
log_2 = lambda x: log(x, 2)

# %%
log_2(8*2) == log_2(2) + log_2(8)
# Out:
# True

# %%
log_2(16/2) == log_2(16) - log_2(2)
# Out:
# True

# %%
log_2(16**3) == 3 * log_2(16)
# Out:
# True

# %%
log_2(1/2**3) == -log_2(2**3)
# Out:
# True

# %% [markdown]
# --------------

# %%
import sympy as sp

# %%
x = sp.symbols('x')
f_ = x**-1
sp.diff(sp.diff(sp.diff(f_)))
# Out:
# -6/x**4

# %%
f2 = x**2 + 2*x**-5
f2_ = sp.lambdify(x, f2, 'numpy')
xs = np.arange(1,4)
f2
# Out:
# x**2 + 2/x**5

# %%
f2_(xs)
# Out:
# array([3.        , 4.0625    , 9.00823045])

# %%
f    = lambda x:    x**-1
df   = lambda x:   -x**-2
ddf  = lambda x:  2*x**-3
dddf = lambda x: -6*x**-4

# %%
x_ = .5
f(x_), df(x_), ddf(x_), dddf(x_)
# Out:
# (2.0, -4.0, 16.0, -96.0)

# %%
x = np.linspace(.1,10,100)

fig = plt.figure(figsize=(5,12))
ax1 = fig.add_axes([.05, .7, .8, .2])
ax2 = fig.add_axes([.05, .46, .8, .2])
ax3 = fig.add_axes([.05, .23, .8, .2])
ax4 = fig.add_axes([.05, .0, .8, .2])

for f_, ax in zip((f, df, ddf, dddf), (ax1,ax2,ax3,ax4)):
    ax.plot(x, f_(x))

# %%
dddf(2), -6 * 1/16
# Out:
# (-0.375, -0.375)

# %%
3**5
# Out:
# 243

# %%
plt.plot(x, 10*x**2 + 2*x**-5)

# %%
0b1 + 0b1/0b11
# Out:
# 1.3333333333333333

# %%
0b100 / 0b11
# Out:
# 1.3333333333333333

# %%
bin(int(.2e3))
# Out:
# '0b11001000'

# %%
16 >> 1
# Out:
# 8

# %%
16 << 1
# Out:
# 32

# %%
0b1 << 1
# Out:
# 2

# %%
for i in range(10):
    print(bin(i))
# Out:
# 0b0
# 0b1
# 0b10
# 0b11
# 0b100
# 0b101
# 0b110
# 0b111
# 0b1000
# 0b1001

# %%
for i in range(10):
    print(1000 << i)
# Out:
# 1000
# 2000
# 4000
# 8000
# 16000
# 32000
# 64000
# 128000
# 256000
# 512000

# %%
0b0011 & 0b1111
# Out:
# 3

# %%
0b1001 | 0b0011
# Out:
# 11

# %%
0b1001 ^ 0b0110
# Out:
# 15

# %%
~0b1001, 0b1001
# Out:
# (-10, 9)

# %%
~(-10)
# Out:
# 9

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
x = np.linspace(-1, 6, 100)
f = lambda w: 3 + (.5*w -2)**2

# %%
plt.plot(x, f(x))
