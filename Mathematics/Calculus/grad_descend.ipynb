# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = '0.3'

# %%
#%matplotlib notebook
# %matplotlib inline
#sin_ = lambda x: np.sin(x)
#cos_ = lambda x: np.cos(x)
#y_sin = sin_(x)
#y_cos = cos_(x)
#x = np.linspace(0, np.pi*4, 1000)

# for i in range(1000):    

#     new_x = curr_pos[0] - l_rate * der_func(curr_pos[0])
#     new_y = func(new_x)
#     curr_pos= (new_x, new_y)    
    
#     plt.axes().set_facecolor('black')
#     plt.plot(x2, y, c='green',zorder=1)
#     plt.scatter(curr_pos[0], curr_pos[1],zorder=2,color='red')
#     plt.pause(.001)
#     plt.clf()

# %%
func = lambda x: x**2
d_func = lambda x: 2*x


x = np.arange(-100,100,1)
f_x = func(x)
df_x = d_func(x)
l_rate = .1

curr_pos = (5, func(5))
new_x = curr_pos[0] - l_rate * der_func(curr_pos[0])
new_y = func(new_x)

print(new_x, new_y)
print(curr_pos)

S = []

L = np.arange(5,3.9,-.1)
start = (L[0], func(L[0]))
# Out:
# 4.0 16.0
# (5, 25)

# %%
plt.axes().set_facecolor('black')
plt.plot(x[100:110], f_x[100:110], c='green',zorder=1)
plt.scatter(curr_pos[0], curr_pos[1],zorder=2,color='red')
plt.scatter(new_x, new_y,color='red')

# %%
plt.axes().set_facecolor('black')
plt.scatter(x[100:110], df_x[100:110], c='red',zorder=1)
