# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = '0.2'

# %%
func = lambda x: x**2
d_func = lambda x: 2*x

f_sin = lambda x: np.sin(x)
f_cos = lambda x: np.cos(x)

x1 = np.linspace(np.pi, np.pi*3, 1000)
y_sin = f_sin(x1)
y_cos = f_cos(x1)


x2 = np.arange(-100,100,1)
f_x = func(x2)
df_x = d_func(x2)

# %%
def calculate_positions(start, l_rate, func, d_func, n):
    positions = [(start, func(start))]
    curr_pos = (start, func(start))

    for _ in range(n - 1):
        new_x = curr_pos[0] - l_rate * d_func(curr_pos[0])
        new_y = func(new_x)
        curr_pos = (new_x, new_y)
        positions.append(curr_pos)
        
    return np.array(positions)

# %%
A = calculate_positions(8,.1,func,d_func,15)
B = calculate_positions(6.5,.1,f_sin,f_cos,15)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10,4))
ax1.set_facecolor('black')
ax2.set_facecolor('black')

ax1.plot(x2[100:110], f_x[100:110], c='green',zorder=1)
ax1.scatter(A[:,0], A[:,1],zorder=2,color='red', s=10)

ax2.plot(x1, y_sin, c='green',zorder=1)
ax2.scatter(B[:,0], B[:,1],zorder=2,color='red',s=10)
A
# Out:
# array([[ 8.        , 64.        ],
#        [ 6.4       , 40.96      ],
#        [ 5.12      , 26.2144    ],
#        [ 4.096     , 16.777216  ],
#        [ 3.2768    , 10.73741824],
#        [ 2.62144   ,  6.87194767],
#        [ 2.097152  ,  4.39804651],
#        [ 1.6777216 ,  2.81474977],
#        [ 1.34217728,  1.80143985],
#        [ 1.07374182,  1.1529215 ],
#        [ 0.85899346,  0.73786976],
#        [ 0.68719477,  0.47223665],
#        [ 0.54975581,  0.30223145],
#        [ 0.43980465,  0.19342813],
#        [ 0.35184372,  0.123794  ]])

# %%
c = lambda t: (np.sin(t), np.cos(t))
L = np.linspace(0,np.pi*2,100)

circle = list(map(c, L))
np_circle = np.array(circle)
plt.axes().set_facecolor('black')
plt.plot(np_circle[:,0], np_circle[:,1], color='green', linestyle='dotted')
plt.axis('equal')

plt.show()

# %%
t = np.linspace(0, 10*np.pi, 1000)  

r = np.random.randint(0,100, 1000)

x = r * np.cos(t)
y = r * np.sin(t)

plt.axes().set_facecolor('black')
plt.plot(x, y, color='green', linewidth=.4)
plt.axis('equal')

plt.show()

# %%
r
# Out:
# array([23, 31, 89, 37,  6, 37, 38, 17, 78, 59, 79, 97, 66, 87, 91, 29, 15,
#        60, 54, 86, 57, 91, 44, 36, 59, 30, 78, 57, 98, 88, 46,  5, 83,  2,
#        35,  5, 40, 13, 87, 77, 97, 34, 34, 38, 91, 85, 18, 40, 39, 31, 92,
#        82, 78, 34, 51, 34,  9, 39, 18, 48, 43, 82, 92,  9, 17,  0, 50, 88,
#        76, 25, 90, 14, 17,  0, 92, 65, 34, 84, 24, 43, 52, 23, 33, 29, 26,
#        47,  0, 41,  0, 53, 85, 67, 44, 88, 24, 86, 36, 69, 79, 33, 78, 76,
