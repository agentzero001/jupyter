# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
plt.rcParams['figure.facecolor'] = '0.3'

# %%
# %matplotlib inline

# %%
A = np.array([2, 7])
B = np.array([8, 6])

distance = round(np.linalg.norm(B - A), 4)
distance2 = np.sqrt((B[0] - A[0])**2 + (B[1] - A[1])**2)

# %%
distance2, distance
# Out:
# (6.082762530298219, 6.0828)

# %%
plt.figure()
plt.gca().set_facecolor('0.1')

plt.plot([A[0], B[0]], [A[1], B[1]], c='green', zorder=2, label='distance = {}'.format(distance))
plt.scatter(A[0], A[1], c='r', marker='o', zorder=3, label='A = ({}, {})'.format(A[0], A[1]))
plt.scatter(B[0], B[1], c='yellow', marker='o', zorder=3, label='B = ({}, {})'.format(B[0], B[1]))

plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.legend(loc='upper right')
plt.legend().get_frame().set_alpha(0.3)
plt.grid(alpha=0.3,zorder=1)

# %% [markdown]
# ---------

# %%
A = np.array([5, 5])
t = np.linspace(0, 4*np.pi-4*np.pi/100, 100)
points = np.zeros((100, 2))
points[:, 0] = A[0] + 5 * np.cos(t)
points[:, 1] = A[1] + 5 * np.sin(t)
points += np.random.randn(100,2)*.5

# %%
distances = np.linalg.norm(points - A, axis=1)
distances
# Out:
# array([5.11867301, 4.04526945, 4.81234378, 4.84785821, 5.7777634 ,
#        5.27435233, 5.57008624, 4.52154363, 4.54636135, 3.87043349,
#        5.2510547 , 5.21182085, 4.84917776, 5.68350138, 5.21677887,
#        5.33818043, 4.66350734, 5.44868115, 5.80810758, 5.25985195,
#        4.86873584, 4.30213826, 4.32503647, 4.97714189, 4.68209506,
#        5.09633896, 4.61226889, 4.66202602, 5.63365501, 5.44922332,
#        4.8170496 , 4.66348922, 5.76414968, 5.55706166, 5.0697619 ,
#        4.25807447, 5.85925864, 5.52874359, 5.41811972, 5.39526029,
#        4.88637122, 4.98721401, 5.19901859, 5.04420888, 5.62357036,
#        5.57262648, 5.4964672 , 5.11746967, 5.0608756 , 4.21138022,
#        4.79651525, 4.80580623, 6.01154795, 5.45711086, 5.39276188,
#        5.03863525, 5.29354086, 4.94434254, 5.12312333, 4.34987208,
#        5.20509384, 4.70281577, 4.88960918, 5.39636395, 4.44243581,
#        4.55320368, 4.70348733, 4.51323772, 5.37584169, 5.4362896 ,
# ...

# %%
plt.figure()
plt.gca().set_facecolor('0.0')

plt.scatter(A[0], A[1], c='y', marker='o', zorder=3,s=90)
plt.scatter(points[:, 0], points[:, 1], c='red', marker='o', zorder=3,s=10)
for i in range(len(points)):
    plt.plot([A[0], points[i, 0]], [A[1], points[i, 1]],c='green',linewidth=.2, zorder=2)
    
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-2, 12)
plt.ylim(-2, 12)
plt.grid(alpha=0.3,zorder=1)
plt.show()

# %%
# %matplotlib notebook

# %%
A2 = np.array([1, 2, 3])
B2 = np.array([4, 5, 6])

xs = [A2[0], B2[0]]
ys = [A2[1], B2[1]]
zs = [A2[2], B2[2]]

dist = np.sqrt(np.sum(np.square(np.subtract(A2, B2))))
dist2 = np.sqrt((B2[0] - A2[0])**2 + (B2[1] - A2[1])**2 + (B2[2] - A2[2])**2)

# %%
dist, dist2
# Out:
# (5.196152422706632, 5.196152422706632)

# %%
fig = plt.figure()
fig.patch.set_facecolor('0.2')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('0.2')

ax.scatter(A2[0], A2[1], A2[2], c='b', marker='o')
ax.scatter(B2[0], B2[1], B2[2], c='r', marker='o')
ax.plot(xs, ys, zs, c='black')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(0, 7)
ax.set_ylim(0, 7)
ax.set_zlim(0, 7)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# -------

# %%
A1 = np.array([5,5,5])

radius = 6
n = 500
theta = np.random.uniform(0, np.pi, n)
phi = np.random.uniform(0, 2*np.pi, n)

x = A1[0] + radius * np.sin(theta) * np.cos(phi)
y = A1[1] + radius * np.sin(theta) * np.sin(phi) 
z = A1[2] + radius * np.cos(theta)

points_ = np.array([x, y, z]).T
points_ += np.random.normal(loc=0, scale=2, size=(500, 3))

# %%
from scipy.spatial.distance import cdist

# %%
distances2 = cdist(A1.reshape(1,3), points_)
distances_ = np.linalg.norm(points_ - A1, axis=1)
distances_[:8], distances2[:,:8]
# Out:
# (array([4.31762647, 7.19665957, 4.58978176, 6.02262224, 4.41539105,
#         7.84760234, 7.36799042, 7.37199238]),
#  array([[4.31762647, 7.19665957, 4.58978176, 6.02262224, 4.41539105,
#          7.84760234, 7.36799042, 7.37199238]]))

# %%
fig = plt.figure()
fig.patch.set_facecolor('0.2')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('0.2')

ax.scatter(A1[0], A1[1], A1[2], c='black', marker='o',s=300)
ax.scatter(points_[:, 0], points_[:, 1], points_[:, 2], c='r', marker='o')

for i in range(points_.shape[0]):
    plt.plot([A1[0], points_[i, 0]], [A1[1], points_[i, 1]], [A1[2], points_[i, 2]],c='green',linewidth=.5, zorder=2)


ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(-5, 15)
ax.set_ylim(-5, 15)
ax.set_zlim(-5, 15)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.uniform(1,10,(10,2))
# Out:
# array([[8.35978687, 6.3989046 ],
#        [6.21974233, 3.74108967],
#        [4.25027538, 8.10271955],
#        [4.50285565, 5.64901866],
#        [9.72386873, 7.90795961],
#        [5.69513543, 4.64911464],
#        [4.70315453, 2.64490641],
#        [9.52342175, 2.97736705],
#        [8.60650505, 5.74406376],
#        [8.99828572, 2.31978144]])

# %%
a,b,c = np.arange(24).reshape(3,8)
np.array([a,b,c]).T
# Out:
# array([[ 0,  8, 16],
#        [ 1,  9, 17],
#        [ 2, 10, 18],
#        [ 3, 11, 19],
#        [ 4, 12, 20],
#        [ 5, 13, 21],
#        [ 6, 14, 22],
#        [ 7, 15, 23]])

# %%
np.random.normal(loc=0, scale=2, size=(500, 3))
# Out:
# array([[ 3.65307668, -0.34683293, -5.07309189],
#        [ 2.31820303, -0.74070886, -3.8779047 ],
#        [ 2.06517451, -2.17304501, -0.95299482],
#        ...,
#        [-1.27625776, -0.04415637,  2.77150456],
#        [-1.69738637,  1.58326872, -1.5712712 ],
#        [ 0.04373045, -1.41768645, -0.63822643]])
