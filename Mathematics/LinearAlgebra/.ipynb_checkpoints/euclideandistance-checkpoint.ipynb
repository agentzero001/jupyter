# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
plt.rcParams['figure.facecolor'] = '0.3'

# %%
# %matplotlib inline

# %%
A = np.array([2, 7])
B = np.array([8, 6])

distance = round(np.linalg.norm(B - A), 4)
distance2 = np.sqrt((B[0] - A[0])**2 + (B[1] - A[1])**2)

# %%
B - A
# Out:
# array([ 6, -1])

# %%
distance2, distance
# Out:
# (6.082762530298219, 6.0828)

# %%
plt.figure()
plt.gca().set_facecolor('0.1')

plt.plot([A[0], B[0]], [A[1], B[1]], c='green', zorder=2, label='distance = {}'.format(distance))
plt.scatter(A[0], A[1], c='r', marker='o', zorder=3, label='A = ({}, {})'.format(A[0], A[1]))
plt.scatter(B[0], B[1], c='yellow', marker='o', zorder=3, label='B = ({}, {})'.format(B[0], B[1]))

plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.legend(loc='upper right')
plt.legend().get_frame().set_alpha(0.3)
plt.grid(alpha=0.3,zorder=1)

# %% [markdown]
# ---------

# %%
A = np.array([5, 5])
t = np.linspace(0, 2*np.pi-2*np.pi/100, 100)
points = np.zeros((100, 2))
points[:, 0] = A[0] + 5 * np.cos(t)
points[:, 1] = A[1] + 5 * np.sin(t)
points += np.random.randn(100,2)*.5

# %%
distances = np.linalg.norm(points - A, axis=1)
distances
# Out:
# array([0.815531  , 1.59392278, 0.71153531, 1.91965011, 0.65715031,
#        0.73823184, 0.52629956, 1.21482098, 0.83850186, 0.41446528,
#        1.23301441, 1.3415146 , 1.48194102, 1.77193936, 1.16648719,
#        1.09923885, 1.02054613, 1.23684435, 0.93716083, 0.91708066,
#        1.53074008, 0.74267975, 1.00056214, 1.85852163, 0.85396892,
#        1.42753304, 0.75678636, 1.27555788, 2.06382682, 0.9430487 ,
#        1.15523348, 1.8286649 , 1.46904587, 1.43035886, 1.47583564,
#        0.68054614, 0.4470436 , 0.40892352, 1.84656504, 1.39004284,
#        1.82786914, 0.83727679, 1.11212452, 1.42342824, 0.60798914,
#        1.39815276, 0.53086126, 1.49973395, 1.07383372, 1.21416114,
#        0.80611559, 2.12364052, 1.97274506, 1.61583048, 0.86878894,
#        1.16663953, 2.25049146, 1.29278897, 1.50215956, 1.59755705,
#        0.86352266, 0.98068545, 0.67543249, 1.79108208, 0.28714377,
#        1.67798091, 0.37414924, 0.48273813, 0.49688014, 2.12024511,
#        0.58646905, 0.31700445, 0.96653994, 0.82686641, 1.38552452,
#        1.0149134 , 1.49518681, 1.5289149 , 1.11464885, 1.07065063,
#        1.47321955, 0.70066239, 1.47047608, 1.31321499, 0.66782756,
#        0.5335451 , 1.73898125, 0.45355567, 1.05590444, 1.22650101,
#        0.8818655 , 1.52741154, 1.31946496, 1.23885421, 1.00898886,
#        1.29853551, 0.88463325, 0.07440627, 0.62321219, 1.21984297])

# %%
plt.figure()
plt.gca().set_facecolor('0.0')

plt.scatter(A[0], A[1], c='y', marker='o', zorder=3,s=90)
plt.scatter(points[:, 0], points[:, 1], c='red', marker='o', zorder=3,s=10)
for i in range(len(points)):
    plt.plot([A[0], points[i, 0]], [A[1], points[i, 1]],c='green',linewidth=.2, zorder=2)
    
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-2, 12)
plt.ylim(-2, 12)
plt.grid(alpha=0.3,zorder=1)
plt.show()
print(distances)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0.815531   1.59392278 0.71153531 1.91965011 0.65715031 0.73823184
#  0.52629956 1.21482098 0.83850186 0.41446528 1.23301441 1.3415146
#  1.48194102 1.77193936 1.16648719 1.09923885 1.02054613 1.23684435
#  0.93716083 0.91708066 1.53074008 0.74267975 1.00056214 1.85852163
#  0.85396892 1.42753304 0.75678636 1.27555788 2.06382682 0.9430487
#  1.15523348 1.8286649  1.46904587 1.43035886 1.47583564 0.68054614
#  0.4470436  0.40892352 1.84656504 1.39004284 1.82786914 0.83727679
#  1.11212452 1.42342824 0.60798914 1.39815276 0.53086126 1.49973395
#  1.07383372 1.21416114 0.80611559 2.12364052 1.97274506 1.61583048
#  0.86878894 1.16663953 2.25049146 1.29278897 1.50215956 1.59755705
#  0.86352266 0.98068545 0.67543249 1.79108208 0.28714377 1.67798091
#  0.37414924 0.48273813 0.49688014 2.12024511 0.58646905 0.31700445
#  0.96653994 0.82686641 1.38552452 1.0149134  1.49518681 1.5289149
#  1.11464885 1.07065063 1.47321955 0.70066239 1.47047608 1.31321499
#  0.66782756 0.5335451  1.73898125 0.45355567 1.05590444 1.22650101
#  0.8818655  1.52741154 1.31946496 1.23885421 1.00898886 1.29853551
#  0.88463325 0.07440627 0.62321219 1.21984297]

# %%
# %matplotlib notebook

# %%
A2 = np.array([1, 2, 3])
B2 = np.array([4, 5, 6])

xs = [A2[0], B2[0]]
ys = [A2[1], B2[1]]
zs = [A2[2], B2[2]]

dist = np.sqrt(np.sum(np.square(np.subtract(A2, B2))))
dist2 = np.sqrt((B2[0] - A2[0])**2 + (B2[1] - A2[1])**2 + (B2[2] - A2[2])**2)

# %%
dist, dist2
# Out:
# (5.196152422706632, 5.196152422706632)

# %%
fig = plt.figure()
fig.patch.set_facecolor('0.2')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('0.2')

ax.scatter(A2[0], A2[1], A2[2], c='b', marker='o')
ax.scatter(B2[0], B2[1], B2[2], c='r', marker='o')
ax.plot(xs, ys, zs, c='black')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(0, 7)
ax.set_ylim(0, 7)
ax.set_zlim(0, 7)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# -------

# %%
A1 = np.array([5,5,5])

radius = 6
n = 100
theta = np.random.uniform(0, np.pi, n)
phi = np.random.uniform(0, 2*np.pi, n)

x = A1[0] + radius * np.sin(theta) * np.cos(phi)
y = A1[1] + radius * np.sin(theta) * np.sin(phi)
z = A1[2] + radius * np.cos(theta)

points_ = np.array([x, y, z])
points_.shape
# Out:
# (3, 100)

# %%
fig = plt.figure()
fig.patch.set_facecolor('0.2')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('0.2')



ax.scatter(A1[0], A1[1], A1[2], c='black', marker='o',s=300)
ax.scatter(points_[0], points_[1], points_[2], c='r', marker='o')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.set_zlim(0, 10)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.uniform(1,10,(10,2))
# Out:
# array([[3.70759722, 6.22820543],
#        [1.91594748, 3.05733869],
#        [6.18506758, 2.77977612],
#        [7.27993331, 9.72346305],
#        [3.15854741, 1.77520661],
#        [3.6577841 , 7.18782234],
#        [5.53648533, 4.34817382],
#        [5.30640478, 3.82111403],
#        [7.5710355 , 2.92160315],
#        [9.73999733, 5.27354959]])

# %%
a,b,c = np.arange(24).reshape(3,8)
np.array([a,b,c]).T
# Out:
# array([[ 0,  8, 16],
#        [ 1,  9, 17],
#        [ 2, 10, 18],
#        [ 3, 11, 19],
#        [ 4, 12, 20],
#        [ 5, 13, 21],
#        [ 6, 14, 22],
#        [ 7, 15, 23]])
