# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
plt.rcParams['figure.facecolor'] = '0.3'

# %%
# %matplotlib inline

# %%
A = np.array([2, 7])
B = np.array([2, 2])
distance = np.linalg.norm(B - A)

# %%
plt.figure()
plt.gca().set_facecolor('0.4')

plt.plot(A, B, c='black', zorder=0)
plt.scatter(A, B, c='r', marker='o')

label = '{:.2f}'.format(distance)
plt.text(np.mean(A), np.mean(B), label, ha='center', va='bottom', color='black')
plt.text(A[1], A[0], 'A({}, {})'.format(A[1], A[0]), ha='center', va='bottom', color='white')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 10)
plt.ylim(0, 10)

plt.show()

# %%
# %matplotlib notebook

# %%
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

dist = np.sqrt(np.sum(np.square(np.subtract(A, B))))

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:charcoal')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('xkcd:charcoal')

ax.scatter(A[0], A[1], A[2], c='b', marker='o')
ax.scatter(B[0], B[1], B[2], c='r', marker='o')

xs = [A[0], B[0]]
ys = [A[1], B[1]]
zs = [A[2], B[2]]
ax.plot(xs, ys, zs, c='black')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(0, 7)
ax.set_ylim(0, 7)
ax.set_zlim(0, 7)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
