# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = '0.3'

# %%
np.random.seed(42)

x1 = np.random.randint(10,100, size=(20))
y1 = x1 + np.random.randint(1,15, size=(20))

x1, y1
# Out:
# (array([61, 24, 81, 70, 30, 92, 96, 84, 84, 97, 33, 12, 31, 62, 11, 97, 39,
#         47, 11, 73]),
#  array([ 73,  29,  82,  82,  40,  98, 109,  96,  93,  98,  44,  23,  41,
#          74,  23, 111,  53,  61,  14,  85]))

# %%
plt.figure(facecolor='.2',dpi = 100)
plt.axes().set_facecolor('black')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='green', alpha=.5)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

def lift(arr):
    arr = np.array(arr)
    return arr.reshape((arr.shape[0], 1))

model = LinearRegression()
model.fit(lift(x1), lift(y1))
# Out:
# LinearRegression()

# %%
# model.get_params()
# model.__dict__
model.predict([[40]])
# Out:
# array([[49.81368726]])

# %%
model.coef_[0][0], model.intercept_[0]
# Out:
# (0.993212700768037, 10.085179231413903)

# %% [markdown]
# f(x) = mx + b
#
# m = (f(3) - f(1)) / 3 - 1
#
# b = f(0)

# %%
values = model.predict([[1],[3]])
m = (values[1] - values[0]) / 2
b = model.predict([[0]])[0]
m = m[0]; b = b[0]
m, b
# Out:
# (0.9932127007680371, 10.085179231413903)

# %%
plt.figure(facecolor='.2',dpi = 100)
plt.axes().set_facecolor('black')
plt.axis([0,110 ,0, 120])
plt.scatter(x1,y1, color='green',zorder=3)
plt.plot([1, 120], model.predict([[1],[120]]), color ='red',zorder=2)

plt.grid(zorder=1, alpha=.2)
plt.show()

# %%
# %matplotlib inline

# %% [markdown]
# $ r(a, b) = X_{\text{sq}} \cdot a^2 + 2 \cdot \sum_{i=1}^{n} x_{1i} \cdot a \cdot b + n \cdot b^2 - 2 \cdot XY \cdot a - 2 \cdot \sum_{i=1}^{n} y_{1i} \cdot b + Y_{\text{sq}} $

# %%
Xsq = np.sum(x1*x1)
Ysq = np.sum(y1*y1)
XY = np.sum(x1*y1)
n = len(x1)

a, b = np.meshgrid(np.linspace(.9, 1.2, 1000), np.linspace(9.9, 10.2, 1000))
r = (Xsq * a * a) + (2 * np.sum(x1) * a * b) + (n * b * b) - (2 * XY * a) - (2 * np.sum(y1) * b) + Ysq

fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.plot_surface(a, b, r, color = 'black',alpha=.8)
ax.scatter(m, b, [.1], color='red', s=70)
plt.show()

# %%
#This function returns the index of the minimum value when the array is flattened.
r.argmin()
# Out:
# 2871

# %%
#This function converts a flattened index back into a tuple of indices in the original array shape.
min_index = np.unravel_index(r.argmin(), r.shape)
min_index
# Out:
# (0, 2871)

# %%
r[min_index], r.min()
# Out:
# (334.5293716302258, 334.5293716302258)

# %%
a[min_index], b[min_index]
# Out:
# (0.9861386138613861, 10.6)

# %%
#in the cells below you can see that the optimal values of a and b are approx 0.993 and 10.085 respectively
#this is just another way of visualizing 3dim.
a, b = np.meshgrid(np.linspace(.8, 1.2, 1000), np.linspace(6.5, 7.5, 1000))
r = (Xsq * a * a) + (2 * np.sum(x1) * a * b) + (n * b * b) - (2 * XY * a) - (2 * np.sum(y1) * b) + Ysq

plt.imshow(r, cmap='viridis', extent=(0, 2, 9.0, 11.2), aspect='auto')
plt.scatter([.993], [10.085],color='black')
plt.colorbar()
plt.xlabel('a')
plt.ylabel('b')
plt.title('Parameter Space Visualization')
plt.show()

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5 * np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,10, size=(20))
c1
# Out:
# array([9, 3, 7, 6, 8, 7, 4, 1, 4, 7, 9, 8, 8, 0, 8, 6, 8, 7, 0, 7])

# %%
# %matplotlib inline

# %%
fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1, c1, b1,c='Black')
plt.show()

# %%
e1 = np.stack((a1, c1), axis=0)
e1
# Out:
# array([[64, 73, 12, 60, 16, 30, 82, 48, 27, 13, 98, 69, 23, 18, 99, 62,
#         11, 93, 69, 80],
#        [ 9,  3,  7,  6,  8,  7,  4,  1,  4,  7,  9,  8,  8,  0,  8,  6,
#          8,  7,  0,  7]])

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5 * np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,4, size=(20))

model = LinearRegression()
model.fit(np.stack((a1,c1), axis=1), lift(b1))
# Out:
# LinearRegression()

# %%
m, v = np.meshgrid(np.linspace(10,100,4), np.linspace(-0.5,4.5,4))
m, v
# Out:
# (array([[ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.]]),
#  array([[-0.5       , -0.5       , -0.5       , -0.5       ],
#         [ 1.16666667,  1.16666667,  1.16666667,  1.16666667],
#         [ 2.83333333,  2.83333333,  2.83333333,  2.83333333],
#         [ 4.5       ,  4.5       ,  4.5       ,  4.5       ]]))

# %%
g = np.stack((m.flatten(),v.flatten()), axis = 1)
g
# Out:
# array([[ 10.        ,  -0.5       ],
#        [ 40.        ,  -0.5       ],
#        [ 70.        ,  -0.5       ],
#        [100.        ,  -0.5       ],
#        [ 10.        ,   1.16666667],
#        [ 40.        ,   1.16666667],
#        [ 70.        ,   1.16666667],
#        [100.        ,   1.16666667],
#        [ 10.        ,   2.83333333],
#        [ 40.        ,   2.83333333],
#        [ 70.        ,   2.83333333],
#        [100.        ,   2.83333333],
#        [ 10.        ,   4.5       ],
#        [ 40.        ,   4.5       ],
#        [ 70.        ,   4.5       ],
#        [100.        ,   4.5       ]])

# %%
model.predict(g)[:,0].shape
# Out:
# (16,)

# %%
g = model.predict(g)[:,0].reshape(4,4)
g
# Out:
# array([[ 13.34658043,  44.58022044,  75.81386046, 107.04750047],
#        [ 14.21256145,  45.44620146,  76.67984148, 107.91348149],
#        [ 15.07854247,  46.31218248,  77.5458225 , 108.77946251],
#        [ 15.94452349,  47.17816351,  78.41180352, 109.64544353]])

# %%
fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='black')
ax.plot_surface(m,v,g, alpha=.5, color='red')
plt.show()

# %%
model.predict([[ 10.0,3.0]]),model.predict([[ 40.0,2.0]])
# Out:
# (array([[15.16514057]]), array([[45.87919197]]))
