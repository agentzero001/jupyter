# %%
# %run ann_example.py

# %%
min(err)
# Out:
# 0.1002878602262246

# %%
ys, yh
# Out:
# (array([[-28.93693694],
#         [-26.95495495],
#         [-21.48948949],
#         [-20.88888889],
#         [-20.04804805],
#         [-16.92492492],
#         [-16.62462462],
#         [ -6.11411411],
#         [ -5.51351351],
#         [ -3.89189189],
#         [ -3.29129129],
#         [ 11.96396396],
#         [ 12.2042042 ],
#         [ 12.86486486],
#         [ 16.70870871]]),
#  array([[-28.93300272],
#         [-26.95294045],
#         [-21.48988302],
#         [-20.88839511],
#         [-20.04809438],
#         [-16.92503033],
#         [-16.62459558],
#         [ -6.11407664],
#         [ -5.51352294],
#         [ -3.89213037],
#         [ -3.29116386],
#         [ 11.96476701],
#         [ 12.2030345 ],
#         [ 12.86541126],
#         [ 16.70869125]]))

# %%
xs
# Out:
# array([[ 1.        , -7.01701702],
#        [ 1.        , -6.7967968 ],
#        [ 1.        , -4.93493493],
#        [ 1.        , -0.25025025],
#        [ 1.        ,  1.25125125],
#        [ 1.        ,  2.97297297],
#        [ 1.        ,  5.53553554],
#        [ 1.        ,  5.6956957 ],
#        [ 1.        ,  6.2962963 ],
#        [ 1.        ,  6.81681682],
#        [ 1.        ,  7.0970971 ],
#        [ 1.        ,  8.11811812],
#        [ 1.        ,  8.81881882],
#        [ 1.        ,  8.85885886],
#        [ 1.        ,  9.07907908]])
