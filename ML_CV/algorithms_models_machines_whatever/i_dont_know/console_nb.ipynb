# %%
# %run ann_example.py

# %%
plt.plot(data_unique,ys)

# %%
data_unique, ys
# Out:
# (array([[-9.45945946],
#         [-7.07707708],
#         [-6.13613614],
#         [-3.89389389],
#         [-2.53253253],
#         [-1.83183183],
#         [ 0.27027027],
#         [ 0.29029029],
#         [ 1.01101101],
#         [ 2.35235235],
#         [ 4.23423423],
#         [ 5.35535536],
#         [ 8.3983984 ],
#         [ 8.5985986 ],
#         [ 8.83883884]]),
#  array([[8.94813733e+01],
#         [5.00850200e+01],
#         [3.76521667e+01],
#         [1.51624097e+01],
#         [6.41372103e+00],
#         [3.35560786e+00],
#         [7.30460190e-02],
#         [8.42684526e-02],
#         [1.02214326e+00],
#         [5.53356159e+00],
#         [1.79287396e+01],
#         [2.86798310e+01],
#         [7.05330957e+01],
#         [7.39358979e+01],
#         [7.81250720e+01]]))

# %%
np.unique(np.random.choice(np.linspace(-10,10,1000), (obs, 1)), axis=0)
# Out:
# array([[-9.77977978],
#        [-7.61761762],
#        [-6.73673674],
#        [-6.53653654],
#        [-6.07607608],
#        [-4.67467467],
#        [-4.35435435],
#        [-3.73373373],
#        [-3.35335335],
#        [-2.81281281],
#        [-2.53253253],
#        [-1.53153153],
#        [-0.09009009],
#        [ 1.47147147],
#        [ 2.13213213]])

# %%
data_unique[0]**2
# Out:
# array([89.48137327])

# %%
8.94813733e-01
# Out:
# 0.894813733
