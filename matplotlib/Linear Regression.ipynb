# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x1 = np.random.randint(10,100, size=(20))
y1 = x1 + 0.5*np.random.randint(2,30, size=(20))

x1,y1
# Out:
# (array([95, 87, 53, 97, 35, 34, 49, 22, 88, 49, 34, 42, 12, 61, 63, 44, 90,
#         85, 42, 73]),
#  array([ 96.5,  99.5,  60.5, 106. ,  44. ,  40.5,  63.5,  25.5,  94. ,
#          50.5,  35. ,  49.5,  23.5,  63.5,  77.5,  48.5,  97. ,  87.5,
#          50.5,  86.5]))

# %%
plt.figure(facecolor='grey',dpi = 100)
plt.axes().set_facecolor('grey')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='black')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Xsq = np.sum(x1*x1)
# Ysq = np.sum(y1*y1)
# XY = np.sum(x1*y1)
# n = len(x1)

# %matplotlib notebook

# from mpl_toolkits.mplot3d import Axes3D

# a,b = np.meshgrid(np.linspace(-1,3,50), np.linspace(-10,10,50))
# r = (Xsq * a * a) + (2 * np.sum(x1) * a * b) + (n * b * b) - (2 * XY * a) - (2 * np.sum(y1) * b) + Ysq

# fig = plt.figure(facecolor='grey')
# ax = fig.gca(projection = '3d')
# ax.set_facecolor('grey')
# ax.set_xlabel('a')
# ax.set_ylabel('b')
# ax.plot_surface(a,b,r,color = 'black')
# plt.show()

# %%
def lift(arr):
    arr = np.array(arr)
    return arr.reshape((arr.shape[0],1))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(lift(x1), lift(y1))
# Out:
# LinearRegression()

# %%
model.predict([[40]])
# Out:
# array([[49.98546702]])

# %%
plt.figure(facecolor='grey',dpi = 100)
plt.axes().set_facecolor('grey')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='black',zorder=3)
plt.plot([1,120],model.predict([[1],[120]]), color ='red',zorder=2)
plt.grid(zorder=1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,10, size=(20))

# %%
#%matplotlib notebook

# %%
fig = plt.figure(facecolor='grey')
ax = fig.gca(projection = '3d')
ax.set_facecolor('grey')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='Black')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
e1 = np.stack((a1,c1), axis = 1)
e1
# Out:
# array([[85,  0],
#        [58,  3],
#        [79,  6],
#        [93,  4],
#        [12,  9],
#        [19,  4],
#        [69,  7],
#        [29,  8],
#        [42,  8],
#        [99,  7],
#        [97,  0],
#        [99,  4],
#        [81,  4],
#        [12,  7],
#        [68,  7],
#        [54,  2],
#        [61,  6],
#        [85,  8],
#        [55,  9],
#        [27,  6]])

# %%
#a1 und c1: unabhänige variablen (input)
#b1: abhängige variable (output)

a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,4, size=(20))


model = LinearRegression()
model.fit(np.stack((a1,c1), axis=1),lift(b1))


sss =np.stack((a1,c1), axis=1)

sss
# Out:
# array([[20,  2],
#        [56,  3],
#        [51,  1],
#        [11,  2],
#        [52,  0],
#        [41,  1],
#        [26,  0],
#        [68,  3],
#        [60,  0],
#        [70,  3],
#        [86,  3],
#        [68,  1],
#        [57,  0],
#        [20,  2],
#        [19,  3],
#        [60,  2],
#        [53,  0],
#        [54,  0],
#        [99,  2],
#        [77,  0]])

# %%
m,v = np.meshgrid(np.linspace(10,100,4), np.linspace(-0.5,4.5,4))
m,v
# Out:
# (array([[ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.]]),
#  array([[-0.5       , -0.5       , -0.5       , -0.5       ],
#         [ 1.16666667,  1.16666667,  1.16666667,  1.16666667],
#         [ 2.83333333,  2.83333333,  2.83333333,  2.83333333],
#         [ 4.5       ,  4.5       ,  4.5       ,  4.5       ]]))

# %%
g = np.stack((m.flatten(),v.flatten()), axis = 1)
g
# Out:
# array([[ 10.        ,  -0.5       ],
#        [ 40.        ,  -0.5       ],
#        [ 70.        ,  -0.5       ],
#        [100.        ,  -0.5       ],
#        [ 10.        ,   1.16666667],
#        [ 40.        ,   1.16666667],
#        [ 70.        ,   1.16666667],
#        [100.        ,   1.16666667],
#        [ 10.        ,   2.83333333],
#        [ 40.        ,   2.83333333],
#        [ 70.        ,   2.83333333],
#        [100.        ,   2.83333333],
#        [ 10.        ,   4.5       ],
#        [ 40.        ,   4.5       ],
#        [ 70.        ,   4.5       ],
#        [100.        ,   4.5       ]])

# %%
g = model.predict(g)[:,0].reshape(4,4)
g
# Out:
# array([[ 18.07924151,  46.25972828,  74.44021504, 102.6207018 ],
#        [ 18.68655484,  46.8670416 ,  75.04752837, 103.22801513],
#        [ 19.29386817,  47.47435493,  75.6548417 , 103.83532846],
#        [ 19.9011815 ,  48.08166826,  76.26215503, 104.44264179]])

# %%
fig = plt.figure(facecolor='grey')
ax = fig.gca(projection = '3d')
ax.set_facecolor('grey')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='black')
ax.plot_surface(m,v,g, alpha=0.5, color='red' )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
model.predict([[ 10.0,3.0]]),model.predict([[ 40.0,2.0]])
# Out:
# (array([[19.3545995]]), array([[47.17069827]]))
