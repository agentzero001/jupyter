# %% [markdown]
# # $l(\theta_{0},\theta_{1}) = \frac{1}{n} \sum_{i = 1}^{n}(y_{i}- f(x_i))²$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
np.random.seed(9)

x = 3* np.random.rand(20,1)
y = 2 * x + 0.4*np.random.randn(20,1) +1


theta_1 = np.dot(x.ravel(),y.ravel())/np.dot(x.ravel(),x.ravel())


plt.figure(facecolor='grey',dpi = 100)
plt.axes().set_facecolor('grey')
plt.axis([0,4,0,10])
plt.scatter(x,y, color='black')
axis = plt.gca()
xmin,xmax = axis.get_xlim()
plt.plot([xmin,xmax], [xmin*theta_1, xmax*theta_1],'red') 

plt.xlabel('$x$',fontsize= 20)
plt.ylabel('$y$',fontsize= 20,rotation= 0)


plt.show()
[xmin*theta_1, xmax*theta_1]
# Out:
# [0.0, 9.948739593984468]

# %%
np.random.seed(7)
x = 3* np.random.rand(20,1)
y = 2 * x + 0.4*np.random.randn(20,1)**2

x1 = np.linspace(0,3,2)
y1 = 3.2* x1 +0.4

plt.figure(facecolor='grey',dpi = 100)
plt.axes().set_facecolor('grey')
plt.axis([0,3,0,6]) 
plt.plot(x1,y1, c = 'red')
plt.scatter(x,y, color='black')
plt.xlabel('$x$',fontsize= 18)
plt.ylabel('$y$',fontsize= 18,rotation= 0)
plt.show()

# %%
x1 = np.random.randint(10,100, size=(20))
y1 = x1 + 0.5*np.random.randint(2,30, size=(20))


plt.figure(facecolor='grey',dpi = 100)
plt.axes().set_facecolor('grey')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='black')
#plt.plot(x2,y2, color ='red')
plt.show()

# %%
Xsq = np.sum(x1*x1)
Ysq = np.sum(y1*y1)
XY = np.sum(x1*y1)
n = len(x1)

# %%
#%matplotlib notebook

# %%
#from mpl_toolkits.mplot3d import Axes3D

#a,b = np.meshgrid(np.linspace(-1,3,50), np.linspace(-10,10,50))
#r = (Xsq * a * a) + (2 * np.sum(x1) * a * b) + (n * b * b) - (2 * XY * a) - (2 * np.sum(y1) * b) + Ysq

#fig = plt.figure()
#ax = fig.gca(projection = '3d')
#ax.set_xlabel('a')
#ax.set_ylabel('b')
#ax.plot_surface(a,b,r)
#plt.show()

# %%
def lift(arr):
    arr = np.array(arr)
    return arr.reshape((arr.shape[0],1))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(lift(x1), lift(y1))
# Out:
# LinearRegression()

# %%
model.predict([[40]])
# Out:
# array([[47.64322153]])

# %%
plt.figure(facecolor='grey',dpi = 100)
plt.axes().set_facecolor('grey')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='black',zorder=3)
plt.plot([1,120],model.predict([[1],[120]]), color ='red',zorder=2)
plt.grid(zorder=1)
plt.show()

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,10, size=(20))

# %%
# %matplotlib notebook

# %%
fig = plt.figure(facecolor='grey')
ax = fig.gca(projection = '3d')
ax.set_facecolor('grey')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='Black')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\jensm\AppData\Local\Temp\ipykernel_11936\2900267202.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d')

# %%
e1 = np.stack((a1,c1), axis = 1)
e1
# Out:
# array([[53,  5],
#        [97,  1],
#        [87,  6],
#        [60,  9],
#        [49,  8],
#        [13,  6],
#        [39,  5],
#        [22,  9],
#        [86,  7],
#        [89,  5],
#        [39,  4],
#        [18,  9],
#        [64,  6],
#        [48,  8],
#        [80,  1],
#        [31,  5],
#        [54,  5],
#        [17,  8],
#        [91,  3],
#        [79,  7]])

# %%
#a1 und c1: unabhänige variablen (input)
#b1: abhängige variable (output)

a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,4, size=(20))


model = LinearRegression()
model.fit(np.stack((a1,c1), axis=1),lift(b1))


sss =np.stack((a1,c1), axis=1)

sss
# Out:
# array([[65,  1],
#        [22,  3],
#        [86,  2],
#        [46,  0],
#        [81,  0],
#        [95,  1],
#        [68,  1],
#        [51,  2],
#        [25,  1],
#        [53,  1],
#        [69,  3],
#        [92,  3],
#        [73,  2],
#        [38,  0],
#        [26,  1],
#        [15,  2],
#        [45,  2],
#        [87,  2],
#        [42,  0],
#        [97,  2]])

# %%
m,v = np.meshgrid(np.linspace(10,100,4), np.linspace(-0.5,4.5,4))
m,v
# Out:
# (array([[ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.]]),
#  array([[-0.5       , -0.5       , -0.5       , -0.5       ],
#         [ 1.16666667,  1.16666667,  1.16666667,  1.16666667],
#         [ 2.83333333,  2.83333333,  2.83333333,  2.83333333],
#         [ 4.5       ,  4.5       ,  4.5       ,  4.5       ]]))

# %%
g = np.stack((m.flatten(),v.flatten()), axis = 1)
g
# Out:
# array([[ 10.        ,  -0.5       ],
#        [ 40.        ,  -0.5       ],
#        [ 70.        ,  -0.5       ],
#        [100.        ,  -0.5       ],
#        [ 10.        ,   1.16666667],
#        [ 40.        ,   1.16666667],
#        [ 70.        ,   1.16666667],
#        [100.        ,   1.16666667],
#        [ 10.        ,   2.83333333],
#        [ 40.        ,   2.83333333],
#        [ 70.        ,   2.83333333],
#        [100.        ,   2.83333333],
#        [ 10.        ,   4.5       ],
#        [ 40.        ,   4.5       ],
#        [ 70.        ,   4.5       ],
#        [100.        ,   4.5       ]])

# %%
g = model.predict(g)[:,0].reshape(4,4)
g
# Out:
# array([[ 18.20829815,  48.87383634,  79.53937453, 110.20491272],
#        [ 16.3143606 ,  46.97989879,  77.64543697, 108.31097516],
#        [ 14.42042304,  45.08596123,  75.75149942, 106.41703761],
#        [ 12.52648549,  43.19202368,  73.85756186, 104.52310005]])

# %%
fig = plt.figure(facecolor='grey')
ax = fig.gca(projection = '3d')
ax.set_facecolor('grey')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='black')
ax.plot_surface(m,v,g, alpha=0.5, color='red' )
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\jensm\AppData\Local\Temp\ipykernel_11936\1791259772.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d')

# %%
model.predict([[ 10.0,3.0]]),model.predict([[ 40.0,2.0]])
# Out:
# (array([[14.23102929]]), array([[46.03293001]]))
