# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
C = np.sin(np.linspace(1,5,80))*5
NC = C + .5 * np.random.randn(80)

# %%
plt.figure(facecolor='0.2')
plt.axes().set_facecolor('0.1')
plt.axis([-1,len(NC),min(NC)-0.1,max(NC)+0.1])
plt.plot(C, 'g.', NC, 'r.')
plt.show()

# %%
def movAvg(a,n):
    r = a.copy()
    for i in range(1, n):
        r += np.concatenate((r[:i] / i , a[:-i]))
    return r / n

# %%
plt.figure(facecolor='0.2')
plt.axes().set_facecolor('0.1')
plt.plot(NC, 'r.', movAvg(NC,4),'g.')
plt.show()

# %%
r1 = np.array([1,2,3,4,5,6,7,8])
r2 = np.concatenate((r1[:2], r1[:-2]))
len(r1), len(r2), len(r1[:1]) + len(r1[:-1])
# Out:
# (8, 8, 8)

# %%
movAvg(NC,4)[5], NC[2:6].sum() / 4, np.mean(NC[2:6]) #interpretation of movAvg
# Out:
# (4.55658126816725, 4.55658126816725, 4.55658126816725)

# %% [markdown]
# -----

# %%
#to use pandas method for moving avg your data format has to be pd.Series
import pandas as pd
p_data = pd.Series(NC)

# %%
plt.figure(facecolor='0.2')
plt.axes().set_facecolor('0.1')
plt.plot(NC, 'r.', p_data.rolling(window=4).mean(),'g.')
plt.show()

# %%
p2 = p_data.rolling(window=8).mean() 
p_data[:8].sum() / 8, p2[7] #basically it does the same as movAvg
# Out:
# (4.488282269538864, 4.488282269538863)

# %%
p2[:10] #But notice
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7    4.488282
# 8    4.475522
# 9    4.553659
# dtype: float64

# %%
#and to fix it
p2[:8] = np.array([(NC[:i+1].sum() / (i+1)) for i in range(8)])
p2[:10]
# Out:
# 0    4.711821
# 1    4.067113
# 2    4.131167
# 3    4.192878
# 4    4.359289
# 5    4.393425
# 6    4.455785
# 7    4.488282
# 8    4.475522
# 9    4.553659
# dtype: float64

# %%
movAvg(NC,8)[:10], p2[:10]
# Out:
# (array([4.71182063, 4.06711323, 4.13116744, 4.19287818, 4.3592891 ,
#         4.39342526, 4.45578536, 4.48828227, 4.47552151, 4.55365926]),
#  0    4.711821
#  1    4.067113
#  2    4.131167
#  3    4.192878
#  4    4.359289
#  5    4.393425
#  6    4.455785
#  7    4.488282
#  8    4.475522
#  9    4.553659
#  dtype: float64)

# %%
def window(a,w):
    pass
