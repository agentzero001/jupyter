# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import PIL
plt.style.use('dark_background')

# %%
img1 = np.array(PIL.Image.open('mypic2.jpg'))

# %%
plt.imshow(img1);

# %%
img1.shape
# Out:
# (720, 579, 3)

# %%
plt.imshow(img1.mean(axis=2), cmap='gray');

# %%
img1.mean(axis=2).shape
# Out:
# (720, 579)
