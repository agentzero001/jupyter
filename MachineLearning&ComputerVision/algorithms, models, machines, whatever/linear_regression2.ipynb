# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = '0.3'

# %%
x1 = np.random.randint(10,100, size=(20))
y1 = x1 + np.random.randint(1,15, size=(20))

x1,y1
# Out:
# (array([59, 67, 81, 63, 61, 93, 22, 77, 15, 82, 40, 81, 84, 50, 25, 37, 85,
#         28, 59, 85]),
#  array([ 63,  81,  90,  74,  66, 106,  23,  83,  20,  90,  49,  89,  93,
#          60,  33,  43,  98,  37,  64,  99]))

# %%
plt.figure(facecolor='.2',dpi = 100)
plt.axes().set_facecolor('black')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='green', alpha=.5)
plt.show()

# %%
# %matplotlib inline

# %%
Xsq = np.sum(x1*x1)
Ysq = np.sum(y1*y1)
XY = np.sum(x1*y1)
n = len(x1)


a,b = np.meshgrid(np.linspace(-1,3,50), np.linspace(-10,10,50))
r = (Xsq * a * a) + (2 * np.sum(x1) * a * b) + (n * b * b) - (2 * XY * a) - (2 * np.sum(y1) * b) + Ysq

fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.plot_surface(a,b,r,color = 'black',alpha=.8)
ax.scatter([1.0],[7.17],[.1],color='red',s=70)
plt.show()

# %%
#in the cells below you can see that the optimal values of a and b are about 1 and 7 respectively
#this is just another way of visualizing 3dim.
a,b = np.meshgrid(np.linspace(.8, 1.2, 100), np.linspace(6.5, 7.5, 100))
r = (Xsq * a * a) + (2 * np.sum(x1) * a * b) + (n * b * b) - (2 * XY * a) - (2 * np.sum(y1) * b) + Ysq

# %%
plt.imshow(r, cmap='viridis', extent=(.8, 1.2, 6.5, 7.5), aspect='auto')
plt.scatter([1.0],[7.17],color='black')
plt.colorbar()
plt.xlabel('a')
plt.ylabel('b')
plt.title('Parameter Space Visualization')
plt.show()

# %%
r
# Out:
# array([[4848.12      , 4690.89483522, 4536.36843179, ..., 2162.71186614,
#         2267.26655239, 2374.52      ],
#        [4842.55032344, 4685.4226181 , 4530.99367411, ..., 2166.59575554,
#         2271.24790123, 2378.59880828],
#        [4836.98472809, 4679.9544822 , 4525.62299765, ..., 2170.48372615,
#         2275.23333129, 2382.68169779],
#        ...,
#        [4326.86351597, 4179.09191715, 4034.01907969, ..., 2558.45128048,
#         2672.4595327 , 2789.16654627],
#        [4321.68971738, 4174.015578  , 4029.04019998, ..., 2562.73104785,
#         2676.83675951, 2793.64123253],
#        [4316.52      , 4168.94332007, 4024.06540149, ..., 2567.01489644,
#         2681.21806754, 2798.12      ]])

# %%
def lift(arr):
    arr = np.array(arr)
    return arr.reshape((arr.shape[0],1))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(lift(x1), lift(y1))
# Out:
# LinearRegression()

# %%
model.predict([[40]])
# Out:
# array([[47.30829572]])

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([[1.00322041]]),
#  'rank_': 1,
#  'singular_': array([110.53935951]),
#  'intercept_': array([7.17947942])}

# %%
model.coef_[0][0], model.intercept_[0]
# Out:
# (1.0032204076455016, 7.179479415170682)

# %% [markdown]
# f(x) = mx + b
#
# m = (f(3) - f(1)) / 3 - 1
#
# b = f(0)

# %%
values = model.predict([[1],[3]])
m = ( values[1] - values[0]) / 2
b = model.predict([[0]])[0]
m[0], b[0]
# Out:
# (1.0032204076455011, 7.179479415170682)

# %%
plt.figure(facecolor='.2',dpi = 100)
plt.axes().set_facecolor('black')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='green',zorder=3)
plt.plot([1,120],model.predict([[1],[120]]), color ='red',zorder=2)

plt.grid(zorder=1,alpha=.2)
plt.show()

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,10, size=(20))
c1
# Out:
# array([3, 5, 6, 7, 7, 3, 4, 5, 4, 8, 2, 2, 2, 9, 2, 2, 9, 1, 5, 5])

# %%
# %matplotlib inline

# %%
fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='Black')
plt.show()

# %%
e1 = np.stack((a1,c1), axis = 0)
e1
# Out:
# array([[96, 40, 74, 90, 63, 27, 26, 84, 65, 61, 57, 88, 15, 94, 14, 78,
#         90, 66, 23, 86],
#        [ 3,  5,  6,  7,  7,  3,  4,  5,  4,  8,  2,  2,  2,  9,  2,  2,
#          9,  1,  5,  5]])

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,4, size=(20))


model = LinearRegression()
model.fit(np.stack((a1,c1), axis=1),lift(b1))
# Out:
# LinearRegression()

# %%
m,v = np.meshgrid(np.linspace(10,100,4), np.linspace(-0.5,4.5,4))
m,v
# Out:
# (array([[ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.]]),
#  array([[-0.5       , -0.5       , -0.5       , -0.5       ],
#         [ 1.16666667,  1.16666667,  1.16666667,  1.16666667],
#         [ 2.83333333,  2.83333333,  2.83333333,  2.83333333],
#         [ 4.5       ,  4.5       ,  4.5       ,  4.5       ]]))

# %%
g = np.stack((m.flatten(),v.flatten()), axis = 1)
g
# Out:
# array([[ 10.        ,  -0.5       ],
#        [ 40.        ,  -0.5       ],
#        [ 70.        ,  -0.5       ],
#        [100.        ,  -0.5       ],
#        [ 10.        ,   1.16666667],
#        [ 40.        ,   1.16666667],
#        [ 70.        ,   1.16666667],
#        [100.        ,   1.16666667],
#        [ 10.        ,   2.83333333],
#        [ 40.        ,   2.83333333],
#        [ 70.        ,   2.83333333],
#        [100.        ,   2.83333333],
#        [ 10.        ,   4.5       ],
#        [ 40.        ,   4.5       ],
#        [ 70.        ,   4.5       ],
#        [100.        ,   4.5       ]])

# %%
model.predict(g)[:,0].shape
# Out:
# (16,)

# %%
g = model.predict(g)[:,0].reshape(4,4)
g
# Out:
# array([[ 17.23999122,  47.76870293,  78.29741464, 108.82612635],
#        [ 17.53112063,  48.05983235,  78.58854406, 109.11725577],
#        [ 17.82225005,  48.35096176,  78.87967347, 109.40838519],
#        [ 18.11337947,  48.64209118,  79.17080289, 109.6995146 ]])

# %%
fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='black')
ax.plot_surface(m,v,g, alpha=.5, color='red' )
plt.show()

# %%
model.predict([[ 10.0,3.0]]),model.predict([[ 40.0,2.0]])
# Out:
# (array([[17.851363]]), array([[48.20539705]]))
