# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.random.randint(10,100, size=(20))
y1 = x1 + np.random.randint(1,15, size=(20))

x1,y1
# Out:
# (array([98, 68, 42, 57, 73, 70, 69, 32, 79, 79, 22, 63, 40, 52, 33, 15, 56,
#         68, 91, 38]),
#  array([111,  80,  45,  69,  87,  82,  74,  36,  82,  92,  29,  76,  49,
#          59,  36,  20,  61,  75, 104,  51]))

# %%
plt.figure(facecolor='.2',dpi = 100)
plt.axes().set_facecolor('black')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='green', alpha=.5)
plt.show()

# %%
# %matplotlib inline

# %%
Xsq = np.sum(x1*x1)
Ysq = np.sum(y1*y1)
XY = np.sum(x1*y1)
n = len(x1)


a,b = np.meshgrid(np.linspace(-1,3,50), np.linspace(-10,10,50))
r = (Xsq * a * a) + (2 * np.sum(x1) * a * b) + (n * b * b) - (2 * XY * a) - (2 * np.sum(y1) * b) + Ysq

fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.plot_surface(a,b,r,color = 'black')
plt.show()

# %%
def lift(arr):
    arr = np.array(arr)
    return arr.reshape((arr.shape[0],1))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(lift(x1), lift(y1))
# Out:
# LinearRegression()

# %%
model.predict([[40]])
# Out:
# array([[47.05855724]])

# %%
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([[1.09225755]]),
#  'rank_': 1,
#  'singular_': array([98.70030395]),
#  'intercept_': array([3.36825519])}

# %%
model.coef_[0][0], model.intercept_[0]
# Out:
# (1.0922575512613237, 3.3682551902892186)

# %% [markdown]
# f(x) = mx + b
#
# m = (f(3) - f(1)) / 3 - 1
#
# b = f(0)

# %%
values = model.predict([[1],[3]])
m = ( values[1] - values[0]) / 2
b = model.predict([[0]])[0]
m[0], b[0]
# Out:
# (1.0922575512613237, 3.3682551902892186)

# %%
plt.figure(facecolor='.2',dpi = 100)
plt.axes().set_facecolor('black')
plt.axis([0,110,0,120])
plt.scatter(x1,y1, color='green',zorder=3)
plt.plot([1,120],model.predict([[1],[120]]), color ='red',zorder=2)

plt.grid(zorder=1,alpha=.2)
plt.show()

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,10, size=(20))
c1
# Out:
# array([2, 4, 8, 3, 3, 5, 6, 2, 9, 9, 0, 7, 6, 2, 2, 6, 7, 3, 2, 4])

# %%
# %matplotlib inline

# %%
fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='Black')
plt.show()

# %%
e1 = np.stack((a1,c1), axis = 0)
e1
# Out:
# array([[52, 71, 12, 51, 39, 79, 71, 68, 14, 24, 77, 98, 43, 19, 53, 67,
#         77, 28, 85, 55],
#        [ 2,  4,  8,  3,  3,  5,  6,  2,  9,  9,  0,  7,  6,  2,  2,  6,
#          7,  3,  2,  4]])

# %%
a1 = np.random.randint(10,100, size=(20))
b1 = a1 + 0.5*np.random.randint(2,30, size=(20))
c1 = np.random.randint(0,4, size=(20))


model = LinearRegression()
model.fit(np.stack((a1,c1), axis=1),lift(b1))
# Out:
# LinearRegression()

# %%
m,v = np.meshgrid(np.linspace(10,100,4), np.linspace(-0.5,4.5,4))
m,v
# Out:
# (array([[ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.],
#         [ 10.,  40.,  70., 100.]]),
#  array([[-0.5       , -0.5       , -0.5       , -0.5       ],
#         [ 1.16666667,  1.16666667,  1.16666667,  1.16666667],
#         [ 2.83333333,  2.83333333,  2.83333333,  2.83333333],
#         [ 4.5       ,  4.5       ,  4.5       ,  4.5       ]]))

# %%
g = np.stack((m.flatten(),v.flatten()), axis = 1)
g
# Out:
# array([[ 10.        ,  -0.5       ],
#        [ 40.        ,  -0.5       ],
#        [ 70.        ,  -0.5       ],
#        [100.        ,  -0.5       ],
#        [ 10.        ,   1.16666667],
#        [ 40.        ,   1.16666667],
#        [ 70.        ,   1.16666667],
#        [100.        ,   1.16666667],
#        [ 10.        ,   2.83333333],
#        [ 40.        ,   2.83333333],
#        [ 70.        ,   2.83333333],
#        [100.        ,   2.83333333],
#        [ 10.        ,   4.5       ],
#        [ 40.        ,   4.5       ],
#        [ 70.        ,   4.5       ],
#        [100.        ,   4.5       ]])

# %%
model.predict(g)[:,0].shape
# Out:
# (16,)

# %%
g = model.predict(g)[:,0].reshape(4,4)
g
# Out:
# array([[ 18.1054072 ,  47.76328889,  77.42117058, 107.07905226],
#        [ 15.96030608,  45.61818776,  75.27606945, 104.93395114],
#        [ 13.81520495,  43.47308664,  73.13096833, 102.78885001],
#        [ 11.67010383,  41.32798552,  70.9858672 , 100.64374889]])

# %%
fig = plt.figure(facecolor='.1')
ax = fig.add_subplot(111, projection='3d')
ax.set_facecolor('.1')
ax.set_xlabel('a')
ax.set_ylabel('b')

ax.scatter(a1,c1,b1,c='black')
ax.plot_surface(m,v,g, alpha=.5, color='red' )
plt.show()

# %%
model.predict([[ 10.0,3.0]]),model.predict([[ 40.0,2.0]])
# Out:
# (array([[13.60069484]]), array([[44.5456372]]))
