# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def profit(x):
    return 0.5*x**2 - 4*x + 8

def derivative(x):
    return x - 4

x = np.linspace(-5, 10, 100)
y = profit(x)
y_prime = derivative(x)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4),facecolor= '0.3')


ax1.plot(x, y)
ax1.set_title("Profit function")
ax1.set_xlabel("x (number of cups)")
ax1.set_ylabel("P(x) (profit)")
ax1.axvline(x=4, color='black', linestyle='--',linewidth=1)
ax1.set_facecolor('grey')

ax2.plot(x, y_prime)
ax2.set_title("Derivative of profit function")
ax2.set_xlabel("x (number of cups)")
ax2.set_ylabel("P'(x) (rate of change of profit)")
ax2.axhline(y=0, color='black', linestyle='--',linewidth=1)
ax2.set_facecolor('grey')

plt.show()

# %%
a = [1,2,3]
b = range(3)

fig, axs = plt.subplots(2, 2, facecolor= '0.3')

for i in range(2):
    for j in range(2):
        axs[i][j].set_facecolor('grey')

axs[0][0].plot(a,b)

# %%
fig, ax = plt.subplots(1, 3, figsize=(10, 2.5),facecolor= '0.3')

for i in range(3):
    ax[i].set_facecolor('grey')

ax[0].plot(a,b)

# %%
x = np.linspace(-5, 5, 100)
y = list(map(lambda a: 1 / (1 + np.exp(-a)), x))

plt.figure(facecolor='grey',dpi = 100)
plt.axes().set_facecolor('grey')

plt.plot(x, y, color = 'black')
plt.xlabel("x")
plt.ylabel("Sigmoid(X)")

plt.show()
